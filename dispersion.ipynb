# %%
from lambwaves import Lamb

# %%
alum = Lamb(thickness=9, 
            nmodes_sym=1, 
            nmodes_antisym=1, 
            fd_max=50000, 
            vp_max=4000, 
            c_L=6142.03, 
            c_S=3093.85)
# Out:
# Calculating symmetric modes..
#
# 0/100 - 0.0 kHz × mm
# 1/100 - 505.1 kHz × mm
# 2/100 - 1010.1 kHz × mm
# 3/100 - 1515.2 kHz × mm
# 4/100 - 2020.2 kHz × mm
# 5/100 - 2525.3 kHz × mm
# 6/100 - 3030.3 kHz × mm
# 7/100 - 3535.4 kHz × mm
# 8/100 - 4040.4 kHz × mm
# 9/100 - 4545.5 kHz × mm
# 10/100 - 5050.5 kHz × mm
# 11/100 - 5555.6 kHz × mm
# 12/100 - 6060.6 kHz × mm
# 13/100 - 6565.7 kHz × mm
# 14/100 - 7070.7 kHz × mm
# 15/100 - 7575.8 kHz × mm
# 16/100 - 8080.8 kHz × mm
# 17/100 - 8585.9 kHz × mm
# 18/100 - 9090.9 kHz × mm
# 19/100 - 9596.0 kHz × mm
# 20/100 - 10101.0 kHz × mm
# 21/100 - 10606.1 kHz × mm
# 22/100 - 11111.1 kHz × mm
# 23/100 - 11616.2 kHz × mm
# 24/100 - 12121.2 kHz × mm
# 25/100 - 12626.3 kHz × mm
# 26/100 - 13131.3 kHz × mm
# 27/100 - 13636.4 kHz × mm
# 28/100 - 14141.4 kHz × mm
# 29/100 - 14646.5 kHz × mm
# 30/100 - 15151.5 kHz × mm
# 31/100 - 15656.6 kHz × mm
# 32/100 - 16161.6 kHz × mm
# 33/100 - 16666.7 kHz × mm
# 34/100 - 17171.7 kHz × mm
# ...

# %%
alum.plot_phase_velocity()
# Out:
# (<Figure size 700x400 with 1 Axes>,
#  <Axes: xlabel='Frequency × thickness [KHz × mm]', ylabel='Phase Velocity [m/s]'>)

# %%
alum.plot_wave_number()
# Out:
# (<Figure size 700x400 with 1 Axes>,
#  <Axes: xlabel='Frequency × thickness [KHz × mm]', ylabel='Wave Number [1/m]'>)
